# %%
import pandas as pd
import numpy as np
import sklearn

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
features = pd.read_csv("C:/Users/Titoran/Documents/2.Cleaning/Regression_Data.csv", index_col = [0])

# %%
features
# Out:
#       Market Value    Join   Age  Outcome  Outlet_90 Min  Outlet_Bild  \
# 1             70.0   665.0  22.0    False              0            0
# 2             30.0  1096.0  26.0    False              0            0
# 4              3.5   634.0  25.0     True              0            0
# 7             48.0  2922.0  30.0    False              0            0
# 8            100.0  1793.0  29.0    False              0            0
# ...            ...     ...   ...      ...            ...          ...
# 1825          25.0     0.0  22.0    False              0            0
# 1826          20.0  2922.0  27.0     True              0            0
# 1827          20.0   181.0  20.0    False              0            0
# 1831          65.0  1059.0  28.0    False              0            0
# 1832          70.0  3269.0  28.0     True              0            0
#
#       Outlet_Calcio mercato  Outlet_Corriere dello Sport  Outlet_ESPN  \
# 1                         0                            0            0
# 2                         0                            0            0
# 4                         0                            0            0
# 7                         0                            1            0
# 8                         0                            0            0
# ...                     ...                          ...          ...
# 1825                      0                            0            0
# 1826                      0                            0            0
# 1827                      0                            0            0
# 1831                      0                            0            0
# 1832                      0                            0            0
#
#       Outlet_Evening Standard  ...  Country_Portugal  Country_Scotland  \
# 1                           0  ...                 0                 0
# 2                           0  ...                 0                 0
# 4                           0  ...                 0                 0
# 7                           0  ...                 0                 0
# 8                           0  ...                 0                 0
# ...                       ...  ...               ...               ...
# 1825                        0  ...                 0                 0
# 1826                        0  ...                 0                 0
# 1827                        0  ...                 0                 0
# 1831                        0  ...                 1                 0
# 1832                        0  ...                 0                 0
#
#       Country_Senegal  Country_Serbia  Country_Spain  Country_Sweden  \
# 1                   0               0              0               0
# 2                   0               0              0               0
# 4                   0               0              1               0
# 7                   1               0              0               0
# 8                   0               0              0               0
# ...               ...             ...            ...             ...
# 1825                0               0              1               0
# 1826                0               0              1               0
# 1827                0               0              0               1
# 1831                0               0              0               0
# 1832                0               0              0               0
#
#       Country_Switzerland  Country_United States  Country_Uruguay  \
# 1                       0                      0                0
# 2                       0                      0                0
# 4                       0                      0                0
# 7                       0                      0                0
# 8                       0                      0                0
# ...                   ...                    ...              ...
# 1825                    0                      0                0
# 1826                    0                      0                0
# 1827                    0                      0                0
# 1831                    0                      0                0
# 1832                    0                      0                0
#
#       Country_Wales
# 1                 0
# 2                 0
# 4                 0
# 7                 0
# 8                 0
# ...             ...
# 1825              0
# 1826              0
# 1827              0
# 1831              0
# 1832              0
#
# [785 rows x 98 columns]

# %%
# Labels are the values we want to predict
labels = np.array(features['Outcome'])

# Remove the labels from the features
# axis 1 refers to the columns
features= features.drop('Outcome', axis = 1)

# Saving feature names for later use
feature_list = list(features.columns)

# Convert to numpy array
features = np.array(features)

# %%
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size = 0.2, random_state = 69)

# %%
# Create the logistic regression model
logreg_model = LogisticRegression(solver='liblinear', C=1, random_state=0, max_iter = 100)

# Train the model on the training data
logreg_model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1, random_state=0, solver='liblinear')

# %%
predictions = logreg_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Calculate accuracy
accuracy = accuracy_score(y_test, predictions)

# Calculate precision
precision = precision_score(y_test, predictions)

# Calculate recall
recall = recall_score(y_test, predictions)

# Calculate F1-score
f1 = f1_score(y_test, predictions)

# Calculate the confusion matrix
conf_matrix = confusion_matrix(y_test, predictions)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Accuracy: 0.6751592356687898
# Precision: 0.45454545454545453
# Recall: 0.3125
# F1-score: 0.3703703703703703
# Confusion Matrix:
# [[91 18]
#  [33 15]]

# %%
from sklearn.datasets import make_hastie_10_2
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.inspection import PartialDependenceDisplay

# %%
features = [0,1,2]
PartialDependenceDisplay.from_estimator(logreg_model, X_train, features)
